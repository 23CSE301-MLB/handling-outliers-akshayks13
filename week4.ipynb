# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import warnings

df = pd.read_csv('credit_scoring_eng.csv')
df
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 0             1   -8437.673028         42       masters degree             0
# 1             1   -4024.803754         36  secondary education             1
# 2             0   -5623.422610         33  Secondary Education             1
# 3             3   -4124.747207         32  secondary education             1
# 4             0  340266.072047         53  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1   -4529.316663         43  secondary education             1
# 21521         0  343937.404131         67  secondary education             1
# 21522         1   -2113.346888         38  secondary education             1
# 21523         3   -3112.481705         38  secondary education             1
# 21524         2   -1984.507589         40  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 0                married                 0      F    employee     0
# 1                married                 0      F    employee     0
# 2                married                 0      M    employee     0
# 3                married                 0      M    employee     0
# 4      civil partnership                 1      F     retiree     0
# ...                  ...               ...    ...         ...   ...
# 21520  civil partnership                 1      F     partner     0
# 21521            married                 0      F     retiree     0
# 21522  civil partnership                 1      M    employee     1
# 21523            married                 0      M    employee     1
# 21524            married                 0      F    employee     0
#
#         total_income                  purpose
# 0      253875.639453    purchase of the house
# 1      112080.014102             car purchase
# 2      145885.952297    purchase of the house
# 3      267628.550329  supplementary education
# 4      158616.077870        to have a wedding
# ...              ...                      ...
# 21520  224791.862382     housing transactions
# 21521  155999.806512        purchase of a car
# 21522   89672.561153                 property
# 21523  244093.050500        buying my own car
# 21524   82047.418899             to buy a car
#
# [21525 rows x 12 columns]

# %%
z_score=np.abs(stats.zscore(df['days_employed']))
outliers=df[z_score>3]
print(outliers.shape)
# Out:
# (0, 12)

# %%
Q1=df['days_employed'].quantile(0.25)
Q3=df['days_employed'].quantile(0.75)
IQR=Q3-Q1 
l_bound=Q1-1.5*IQR 
u_bound=Q3+1.5*IQR 
outliers=df[(df["days_employed"]<l_bound) | (df["days_employed"]>u_bound)]
print(outliers.shape)
# Out:
# (4467, 12)

# %%
df_removed=df[(df["days_employed"]>=l_bound) & (df["days_employed"]<=u_bound)]
df_removed
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 1             1   -4024.803754         36  secondary education             1
# 2             0   -5623.422610         33  Secondary Education             1
# 3             3   -4124.747207         32  secondary education             1
# 5             0    -926.185831         27       masters degree             0
# 6             0   -2879.202052         43       masters degree             0
# ...         ...            ...        ...                  ...           ...
# 21519         1   -2351.431934         37      academic degree             4
# 21520         1   -4529.316663         43  secondary education             1
# 21522         1   -2113.346888         38  secondary education             1
# 21523         3   -3112.481705         38  secondary education             1
# 21524         2   -1984.507589         40  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 1                married                 0      F    employee     0
# 2                married                 0      M    employee     0
# 3                married                 0      M    employee     0
# 5      civil partnership                 1      M     partner     0
# 6                married                 0      F     partner     0
# ...                  ...               ...    ...         ...   ...
# 21519           divorced                 3      M    employee     0
# 21520  civil partnership                 1      F     partner     0
# 21522  civil partnership                 1      M    employee     1
# 21523            married                 0      M    employee     1
# 21524            married                 0      F    employee     0
#
#         total_income                     purpose
# 1      112080.014102                car purchase
# 2      145885.952297       purchase of the house
# 3      267628.550329     supplementary education
# 5      255763.565419       purchase of the house
# 6      240525.971920        housing transactions
# ...              ...                         ...
# 21519  115949.039788  buy commercial real estate
# 21520  224791.862382        housing transactions
# 21522   89672.561153                    property
# 21523  244093.050500           buying my own car
# 21524   82047.418899                to buy a car
#
# [14884 rows x 12 columns]

# %%
df_capped=df.copy()
df_capped["days_employed"]=np.where(df["days_employed"]>u_bound,u_bound,np.where(df["days_employed"]<l_bound,l_bound,df_capped["days_employed"]))
df_capped
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 0             1   -6431.915133         42       masters degree             0
# 1             1   -4024.803754         36  secondary education             1
# 2             0   -5623.422610         33  Secondary Education             1
# 3             3   -4124.747207         32  secondary education             1
# 4             0    3393.395554         53  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1   -4529.316663         43  secondary education             1
# 21521         0    3393.395554         67  secondary education             1
# 21522         1   -2113.346888         38  secondary education             1
# 21523         3   -3112.481705         38  secondary education             1
# 21524         2   -1984.507589         40  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 0                married                 0      F    employee     0
# 1                married                 0      F    employee     0
# 2                married                 0      M    employee     0
# 3                married                 0      M    employee     0
# 4      civil partnership                 1      F     retiree     0
# ...                  ...               ...    ...         ...   ...
# 21520  civil partnership                 1      F     partner     0
# 21521            married                 0      F     retiree     0
# 21522  civil partnership                 1      M    employee     1
# 21523            married                 0      M    employee     1
# 21524            married                 0      F    employee     0
#
#         total_income                  purpose
# 0      253875.639453    purchase of the house
# 1      112080.014102             car purchase
# 2      145885.952297    purchase of the house
# 3      267628.550329  supplementary education
# 4      158616.077870        to have a wedding
# ...              ...                      ...
# 21520  224791.862382     housing transactions
# 21521  155999.806512        purchase of a car
# 21522   89672.561153                 property
# 21523  244093.050500        buying my own car
# 21524   82047.418899             to buy a car
#
# [21525 rows x 12 columns]

# %%
df_log=df.copy()
df_log["days_employed"]=np.log(df["days_employed"]+1)
df_log
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#        children  days_employed  dob_years            education  education_id  \
# 0             1            NaN         42       masters degree             0
# 1             1            NaN         36  secondary education             1
# 2             0            NaN         33  Secondary Education             1
# 3             3            NaN         32  secondary education             1
# 4             0      12.737486         53  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1            NaN         43  secondary education             1
# 21521         0      12.748218         67  secondary education             1
# 21522         1            NaN         38  secondary education             1
# 21523         3            NaN         38  secondary education             1
# 21524         2            NaN         40  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 0                married                 0      F    employee     0
# 1                married                 0      F    employee     0
# 2                married                 0      M    employee     0
# 3                married                 0      M    employee     0
# 4      civil partnership                 1      F     retiree     0
# ...                  ...               ...    ...         ...   ...
# 21520  civil partnership                 1      F     partner     0
# 21521            married                 0      F     retiree     0
# 21522  civil partnership                 1      M    employee     1
# 21523            married                 0      M    employee     1
# 21524            married                 0      F    employee     0
#
#         total_income                  purpose
# 0      253875.639453    purchase of the house
# 1      112080.014102             car purchase
# 2      145885.952297    purchase of the house
# 3      267628.550329  supplementary education
# 4      158616.077870        to have a wedding
# ...              ...                      ...
# 21520  224791.862382     housing transactions
# 21521  155999.806512        purchase of a car
# 21522   89672.561153                 property
# 21523  244093.050500        buying my own car
# 21524   82047.418899             to buy a car
#
# [21525 rows x 12 columns]

# %%
df_imp=df.copy()
med=df_imp["days_employed"].median()
df_imp.loc[(df_imp["days_employed"]<l_bound) & (df_imp["days_employed"]>u_bound),"days_employed"]=med 
df_imp
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 0             1   -8437.673028         42       masters degree             0
# 1             1   -4024.803754         36  secondary education             1
# 2             0   -5623.422610         33  Secondary Education             1
# 3             3   -4124.747207         32  secondary education             1
# 4             0  340266.072047         53  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1   -4529.316663         43  secondary education             1
# 21521         0  343937.404131         67  secondary education             1
# 21522         1   -2113.346888         38  secondary education             1
# 21523         3   -3112.481705         38  secondary education             1
# 21524         2   -1984.507589         40  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 0                married                 0      F    employee     0
# 1                married                 0      F    employee     0
# 2                married                 0      M    employee     0
# 3                married                 0      M    employee     0
# 4      civil partnership                 1      F     retiree     0
# ...                  ...               ...    ...         ...   ...
# 21520  civil partnership                 1      F     partner     0
# 21521            married                 0      F     retiree     0
# 21522  civil partnership                 1      M    employee     1
# 21523            married                 0      M    employee     1
# 21524            married                 0      F    employee     0
#
#         total_income                  purpose
# 0      253875.639453    purchase of the house
# 1      112080.014102             car purchase
# 2      145885.952297    purchase of the house
# 3      267628.550329  supplementary education
# 4      158616.077870        to have a wedding
# ...              ...                      ...
# 21520  224791.862382     housing transactions
# 21521  155999.806512        purchase of a car
# 21522   89672.561153                 property
# 21523  244093.050500        buying my own car
# 21524   82047.418899             to buy a car
#
# [21525 rows x 12 columns]

# %%
import seaborn as sns

# %%
sns.histplot(data=df,x="days_employed",bins=20)
# Out:
# <Axes: xlabel='days_employed', ylabel='Count'>

# %%
sns.boxplot(data=df,x="days_employed")
# Out:
# <Axes: xlabel='days_employed'>

# %%
sns.countplot(x="education",hue="gender",data=df)
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
sns.pairplot(df[["days_employed","debt","gender"]],hue="gender")

# %%
sns.scatterplot(data=df,x="total_income",y="days_employed",hue="gender")
# Out:
# <Axes: xlabel='total_income', ylabel='days_employed'>

# %%
sns.boxplot(data=df,x="gender",y="total_income")
# Out:
# <Axes: xlabel='gender', ylabel='total_income'>
